# %% [markdown]
# # **1 Step** - Raw (Extract) **BRONZE**

# %% [markdown]
# Importando as dependências necessárias:

# %%
# Bibliotecas necessárias
import os
import pandas as pd
import sqlite3
import time
import logging

# %% [markdown]
# Carregando a base de dados:

# %%
# Carregamento da base de dados
df = pd.read_csv('../data/raw/V_OCORRENCIA_AMPLA.csv', sep=';', encoding='utf-8')

# %% [markdown]
# Exibindo os dados carregados:

# %%
# Exibindo o data-set
df.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Atualizado em: 2024-02-29
# ...
